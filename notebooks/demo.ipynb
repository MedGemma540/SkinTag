# %% [markdown]
# # SkinTag: Robust Skin Lesion Classification
#
# Using MedSigLIP embeddings with augmentations for fairness across skin tones.

# %%
import sys
sys.path.append('..')

from src.model.embeddings import EmbeddingExtractor
from src.model.classifier import ZeroShotClassifier
from src.data.augmentations import get_training_transform, get_eval_transform

# %% [markdown]
# ## 1. Load MedSigLIP

# %%
extractor = EmbeddingExtractor()

# %% [markdown]
# ## 2. Zero-Shot Classification Demo

# %%
# Define class descriptions for zero-shot
class_descriptions = [
    "a benign skin lesion",
    "a malignant melanoma skin lesion",
]

classifier = ZeroShotClassifier(extractor, class_descriptions)

# %% [markdown]
# ## 3. Augmentation Visualization

# %%
# TODO: Load sample image and show augmentation effects

# %% [markdown]
# ## 4. Robustness Evaluation

# %%
# TODO: Evaluate model on augmented test sets
# Show per-group accuracy
